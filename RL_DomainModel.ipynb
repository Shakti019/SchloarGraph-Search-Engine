# %% [markdown]
# ### 1. Mount Google Drive
# Mounts Google Drive to access the processed Reinforcement Learning (RL) dataset.

# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 2. Initialize Qdrant Client
# Initializes the connection to the Qdrant Cloud vector database. This client will be used to create the `RL_collection` and upload vectors.

# %%
from qdrant_client import QdrantClient
from qdrant_client.http import models as rest

qdrant_client = QdrantClient(
     url="Enter your api URL***",
     api_key="Enter your Api key***"
)

# %% [markdown]
# ### 3. Inspect Processed Data
# Reads and prints the first line of the processed RL dataset (`rl.jsonl`) to verify the data format before indexing.

# %%
import json

path = "/content/drive/MyDrive/OpenAlex_CS_2025_Data/processed/rl.jsonl"

with open(path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        print(json.loads(line))
        break
# Out:
# {'openalex_id': 'https://openalex.org/W1591675293', 'doi': 'https://doi.org/10.1017/9781009449441.027', 'title': 'Bayesian Inverse Reinforcement Learning', 'publication_year': 2025, 'publication_date': '2025-05-16', 'authors': [{'author_id': 'https://openalex.org/A5111238931', 'name': 'Deepak Ramachandran'}, {'author_id': 'https://openalex.org/A5109409885', 'name': 'Eyal Amir'}], 'concepts': [{'id': 'https://openalex.org/C154945302', 'name': 'Artificial intelligence'}, {'id': 'https://openalex.org/C119857082', 'name': 'Machine learning'}, {'id': 'https://openalex.org/C106189395', 'name': 'Markov decision process'}, {'id': 'https://openalex.org/C41008148', 'name': 'Computer science'}, {'id': 'https://openalex.org/C97541855', 'name': 'Reinforcement learning'}, {'id': 'https://openalex.org/C2780451532', 'name': 'Task (project management)'}, {'id': 'https://openalex.org/C173801870', 'name': 'Heuristic'}, {'id': 'https://openalex.org/C107673813', 'name': 'Bayesian probability'}, {'id': 'https://openalex.org/C181204326', 'name': 'Preference learning'}, {'id': 'https://openalex.org/C98045186', 'name': 'Process (computing)'}, {'id': 'https://openalex.org/C2781249084', 'name': 'Preference'}, {'id': 'https://openalex.org/C159886148', 'name': 'Markov process'}, {'id': 'https://openalex.org/C33923547', 'name': 'Mathematics'}, {'id': 'https://openalex.org/C127413603', 'name': 'Engineering'}, {'id': 'https://openalex.org/C111919701', 'name': 'Operating system'}, {'id': 'https://openalex.org/C105795698', 'name': 'Statistics'}, {'id': 'https://openalex.org/C201995342', 'name': 'Systems engineering'}], 'venue': 'Cambridge University Press eBooks', 'citation_count': 470, 'is_open_access': False, 'oa_status': 'closed', 'url': 'https://openalex.org/W1591675293'}

# %% [markdown]
# ### 4. Full Indexing Pipeline (RL Domain)
# This is the main ingestion script for the Reinforcement Learning domain:
# 1.  **Config**: Sets the collection name (`RL_collection`), batch size, and vector size.
# 2.  **Setup**: Creates the Qdrant collection if it doesn't exist.
# 3.  **Ingest**:
#     *   Reads the `rl.jsonl` file.
#     *   Generates embeddings using `all-MiniLM-L6-v2`.
#     *   Constructs the payload with metadata.
#     *   Uploads points in batches to Qdrant.

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import PointStruct, VectorParams, Distance
from sentence_transformers import SentenceTransformer
import json
from tqdm import tqdm

# ---------------- CONFIG ----------------
COLLECTION = "RL_collection"   # ✅ NEW COLLECTION
BATCH_SIZE = 64             # safer for cloud
VECTOR_SIZE = 384

# ---------------- MODEL -----------------
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# ---------------- QDRANT ----------------
client = QdrantClient(
    url="Enter your api URL***",
    api_key="Enter your Api key***"
    timeout=60  # ✅ IMPORTANT
)

# ---------------- COLLECTION SETUP ----------------
if not client.collection_exists(COLLECTION):
    client.create_collection(
        collection_name=COLLECTION,
        vectors_config=VectorParams(
            size=VECTOR_SIZE,
            distance=Distance.COSINE
        )
    )

# ---------------- INGEST ----------------
points = []
idx = 0

with open(
    "/content/drive/MyDrive/OpenAlex_CS_2025_Data/processed/rl.jsonl",
    "r",
    encoding="utf-8"
) as f:

    for line in tqdm(f, desc="Indexing RL Papers"):
        paper = json.loads(line)

        text = f"{paper.get('title','')} {paper.get('abstract','')}".strip()
        if len(text) < 30:
            continue

        vector = model.encode(text).tolist()

        payload = {
            "openalex_id": paper.get("openalex_id"),
            "doi": paper.get("doi"),
            "title": paper.get("title"),
            "abstract": paper.get("abstract"),
            "publication_year": paper.get("publication_year"),
            "publication_date": paper.get("publication_date"),
            "venue": paper.get("venue"),
            "citation_count": paper.get("citation_count"),
            "is_open_access": paper.get("is_open_access"),
            "oa_status": paper.get("oa_status"),
            "url": paper.get("url"),

            # 🔥 STRUCTURED FIELDS
            "authors": [
                {
                    "id": a.get("author_id"),
                    "name": a.get("name")
                } for a in paper.get("authors", [])
            ],

            "concepts": [
                {
                    "id": c.get("id"),
                    "name": c.get("name")
                } for c in paper.get("concepts", [])
            ]
        }

        points.append(
            PointStruct(
                id=idx,
                vector=vector,
                payload=payload
            )
        )
        idx += 1

        if len(points) == BATCH_SIZE:
            client.upsert(
                collection_name=COLLECTION,
                points=points,
                wait=False  # ✅ avoids timeout
            )
            points = []

# Final flush
if points:
    client.upsert(
        collection_name=COLLECTION,
        points=points,
        wait=False
    )

print("✅ FULL RL COLLECTION INDEXED SUCCESSFULLY")
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Indexing RL Papers: 2963it [01:13, 40.34it/s]
# ✅ FULL RL COLLECTION INDEXED SUCCESSFULLY

# %% [markdown]
# ### 5. Test Retrieval (RL Domain)
# Performs a sanity check on the indexed `RL_collection`:
# 1.  Encodes a test query ("What are the open research gaps?").
# 2.  Searches the collection for the top 5 nearest neighbors.
# 3.  Prints the detailed results to verify retrieval quality.

# %%
from qdrant_client import QdrantClient
from sentence_transformers import SentenceTransformer

model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

client = QdrantClient(
    url="Enter your api URL***",
     api_key="Enter your Api key***"
)

query = "What are the open research gaps ?"
vector = model.encode(query).tolist()

results = client.query_points(
    collection_name="RL_collection"  ,
    query=vector,
    limit=5,
    with_payload=True
)

print(f"Returned points: {len(results.points)}")

for i, hit in enumerate(results.points, start=1):
    p = hit.payload

    print(f"\n--- Result {i} ---")
    print("Score:", round(hit.score, 4))
    print("Title:", p.get("title"))
    print("DOI:", p.get("doi"))
    print("Year:", p.get("publication_year"))
    print("Venue:", p.get("venue"))
    print("Citations:", p.get("citation_count"))
    print("Open Access:", p.get("is_open_access"), "| Status:", p.get("oa_status"))
    print("URL:", p.get("url"))

    # ✅ SAFE abstract handling
    abstract = p.get("abstract")
    if abstract:
        print("Abstract:", abstract[:600])
    else:
        print("Abstract: ❌ Not available")

    # ✅ Authors
    authors = p.get("authors", [])
    if authors:
        print("Authors:", ", ".join(a["name"] for a in authors[:5]))
    else:
        print("Authors: ❌ Not available")

    # ✅ Concepts
    concepts = p.get("concepts", [])
    if concepts:
        print("Concepts:", ", ".join(c["name"] for c in concepts[:6]))
    else:
        print("Concepts: ❌ Not available")
